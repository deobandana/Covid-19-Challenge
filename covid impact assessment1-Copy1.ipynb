# %% [markdown]
# # COVID-19 Imapct Assessment

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data_conf = pd.read_csv(r"E:\Data Analytics\Covid-19-Challenge\Resources\time_series_covid19_confirmed_global_iso3_regions.csv")
data_recov = pd.read_csv(r"E:\Data Analytics\Covid-19-Challenge\Resources\time_series_covid19_recovered_global_iso3_regions.csv")
data_deaths = pd.read_csv(r"E:\Data Analytics\Covid-19-Challenge\Resources\time_series_covid19_deaths_global_iso3_regions.csv")

# %%
type(data_conf)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# # What is a DataFrame?

# %%
data = {'A' : [10,20,30], 'B' : [50,60,70]}
index = [1,2,3]
pd.DataFrame(data, index)
# Out:
#     A   B
# 1  10  50
# 2  20  60
# 3  30  70

# %%
data_conf.head(100)
# Out:
#       Country/Region        Lat        Long  1/22/2020  1/23/2020  1/24/2020  \
# 0      #country+name   #geo+lat    #geo+lon        NaN        NaN        NaN
# 1        Afghanistan   33.93911   67.709953        0.0        0.0        0.0
# 2            Albania    41.1533     20.1683        0.0        0.0        0.0
# 3            Algeria    28.0339      1.6596        0.0        0.0        0.0
# 4            Andorra    42.5063      1.5218        0.0        0.0        0.0
# ..               ...        ...         ...        ...        ...        ...
# 95  Congo (Kinshasa)    -4.0383     21.7587        0.0        0.0        0.0
# 96        Costa Rica     9.7489    -83.7534        0.0        0.0        0.0
# 97     Cote d'Ivoire       7.54     -5.5471        0.0        0.0        0.0
# 98           Croatia       45.1        15.2        0.0        0.0        0.0
# 99              Cuba  21.521757  -77.781167        0.0        0.0        0.0
#
# ...

# %% [markdown]
# # Converting data into list

# %%
L_conf = data_conf.to_numpy().tolist()
L_recov = data_recov.to_numpy().tolist()
L_deaths = data_deaths.to_numpy().tolist()

#L_conf = data_conf.values.tolist()
#L_recov = data_recov.values.tolist()
#L_deaths = data_deaths.values.tolist()

# %% [markdown]
# # Trying to find the location of US in Dataframe

# %%
data_conf.loc[data_conf['Country/Region'] == 'US']
# Out:
#     Country/Region Lat  Long  1/22/2020  1/23/2020  1/24/2020  1/25/2020  \
# 250             US  40  -100        1.0        1.0        2.0        2.0
#
#      1/26/2020  1/27/2020  1/28/2020  ...   2/20/2021   2/21/2021   2/22/2021  \
# 250        5.0        5.0        5.0  ...  28077620.0  28134115.0  28190159.0
#
#       2/23/2021   2/24/2021   2/25/2021   2/26/2021   2/27/2021   2/28/2021  \
# 250  28261595.0  28336097.0  28413388.0  28490179.0  28554466.0  28605671.0
#
#        3/1/2021
# 250  28664481.0
#
# [1 rows x 408 columns]

# %%
conf_US = L_conf[250]             #US
recov_US= L_recov[250]
deaths_US = L_deaths[250]

conf_Spain = L_conf[234]         #Spain
recov_Spain= L_recov[234]
deaths_Spain = L_deaths[234]


conf_Italy= L_conf[153]             #Italy
recov_Italy= L_recov[153]
deaths_Italy = L_deaths[153]
 

conf_Germany = L_conf[134]           #Germany
recov_Germany= L_recov[134]
deaths_Germany = L_deaths[134]


days = range(len(conf_US)) #Total number of columns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-3d0c8480d609> in <module>
# ----> 1 conf_US = L_Conf[250]             #US
#       2 recov_US= L_recov[250]
#       3 deaths_US = L_deaths[250]
#       4
#       5 conf_Spain = L_conf[234]         #Spain
#
# NameError: name 'L_Conf' is not defined

# %%
plt.figure(figsize = (20,15))

plt.subplot(221)
plt.plot(days[5:], conf_US[5:], '-*')
plt.xlabel('Days', size = 16)
plt.ylabel('Confirmed cases' , size = 16)
plt.title('US' , size = 25)
plt.savefig('Confirmed cases vs Days_US.png')

plt.subplot(222)
plt.plot(days[5:], conf_Spain[5:], '-*')
plt.xlabel('Days', size = 16)
plt.ylabel('Confirmed cases' , size = 16)
plt.title('Spain' , size = 25)
plt.savefig('Confirmed cases vs Days_Spain.png')

plt.subplot(223)
plt.plot(days[5:], conf_Italy[5:], '-*')
plt.xlabel('Days', size = 16)
plt.ylabel('Confirmed cases' , size = 16)
plt.title('Italy' , size = 25)
plt.savefig('Confirmed cases vs Days_Italy.png')

plt.subplot(224)
plt.plot(days[5:], conf_Germany[5:], '-*')
plt.xlabel('Days', size = 16)
plt.ylabel('Confirmed cases' , size = 16)
plt.title('Germany' , size = 25)
plt.savefig('Confirmed cases vs Days_Germany.png')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-dbe95361e1d2> in <module>
#       2
#       3 plt.subplot(221)
# ----> 4 plt.plot(days[5:], conf_US[5:], '-*')
#       5 plt.xlabel('Days', size = 16)
#       6 plt.ylabel('Confirmed cases' , size = 16)
#
# NameError: name 'days' is not defined

# %% [markdown]
# # For to find derivative growth

# %%
plt.figure(figsize = (25,15))
x = np.array(days[6:])



plt.subplot(221)
y = np.diff(np.array(conf_US[5:]))
plt.plot(x, y, '-*')
plt.xlabel('Days' , size = 16)
plt.title('US' , size = 25)
plt.savefig('US_derivative growth.png')

plt.subplot(222)
y = np.diff(np.array(conf_Spain[5:]))
plt.plot(x, y, '-*')
plt.xlabel('Days' , size = 16)
plt.title('Spain' , size = 25)
plt.savefig('Spain_derivative growth.png')

plt.subplot(223)
y = np.diff(np.array(conf_Italy[5:]))
plt.plot(x, y, '-*')
plt.xlabel('Days' , size = 16)
plt.title('Italy' , size = 25)
plt.savefig('Italy_derivative growth.png')

plt.subplot(224)
y = np.diff(np.array(conf_Germany[5:]))
plt.plot(x, y, '-*')
plt.xlabel('Days' , size = 16)
plt.title('Germany' , size = 25)
plt.savefig('Germany_derivative growth.png')

# %% [markdown]
# # Percentage recovery cases of four different countries

# %%
f_recov_US = np.array(recov_US[12:])/np.array(conf_US[12:], dtype = float)*100
f_recov_Spain = np.array(recov_US[12:])/np.array(conf_Spain[12:], dtype = float)*100
f_recov_Italy = np.array(recov_US[12:])/np.array(conf_Italy[12:], dtype = float)*100
f_recov_Germany = np.array(recov_US[12:])/np.array(conf_Germany[12:], dtype = float)*100


f_deaths_US = np.array(recov_US[12:])/np.array(conf_US[12:], dtype = float)*100
f_deaths_Spain = np.array(recov_US[12:])/np.array(conf_Spain[12:], dtype = float)*100
f_deaths_Italy = np.array(recov_US[12:])/np.array(conf_Italy[12:], dtype = float)*100
f_deaths_Germany = np.array(recov_US[12:])/np.array(conf_Germany[12:], dtype = float)*100

# %%
f_recov_US

# %%
plt.figure(figsize = (18,15))

plt.subplot(221)
plt.plot(days[12:], f_deaths_US, '-*',days[12:], f_recov_US, '-*')
plt.title('US' , size = 14)
plt.xlim(20,65)
plt.legend(['deaths', 'Recovery'])
plt.xlabel('Days', size = 16)

plt.subplot(222) 
plt.plot(days[12:], f_deaths_Spain, '-*',days[12:], f_recov_Spain, '-*')
plt.title('Spain' , size = 14)
plt.xlim(30,65)
plt.legend(['deaths', 'Recovery'])
plt.xlabel('Days', size = 16)


plt.subplot(223)
plt.plot(days[12:], f_deaths_Italy, '-*',days[12:], f_recov_Italy, '-*')
plt.title('Italy' , size = 14)
plt.xlim(30,65)
plt.legend(['deaths', 'Recovery'])
plt.xlabel('Days', size = 16)


plt.subplot(224)
plt.plot(days[12:], f_deaths_Germany, '-*',days[12:], f_recov_Germany, '-*')
plt.title('Germany' , size = 14)
plt.xlim(30,65)
plt.legend(['deaths', 'Recovery'])
plt.xlabel('Days', size = 16)

# %% [markdown]
# # Comparing with China because of it's 'origination'

# %%
data_conf.loc[data_conf['Country/Region'] == 'China']

# %%
#plt.figure(figsize == (12,8))
#for i in range(60, 92):
   # conf_china = L_conf[i]
   # plt.semilogy(days[5:], conf_china[5:], 1w = 3)
   # plt.text(30, 25000, 'Wuhan(Hubei)', size = 18)
    #plt.title('CHINA: COVID-19 Confirmed Cases', size = 22)
    #plt.xlabel('Days', size = 18)
   # plt.tick_params(labelsize = 18)

# %%
import plotly.graph_objects as go
labels = ['confirmed', 'deaths']
colors = ['blue', 'red']
mode_size = [6,8]
line_size = []
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-c233edd52da7> in <module>
# ----> 1 import plotly.graph_objects as go
#       2 labels = ['confirmed', 'deaths']
#       3 colors = ['blue', 'red']
#       4 mode_size = [6,8]
#       5 line_size = []
#
# ModuleNotFoundError: No module named 'plotly'
